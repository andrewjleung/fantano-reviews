# %%
import pandas as pd
import seaborn as sns
from reviews import Reviews

REVIEWS_FILENAME = "./data/reviews.csv"

# %%
reviews = Reviews(filename=REVIEWS_FILENAME)
reviews.get_all_genres()
# Out:
# {'teen pop',
#  'funktronic',
#  'industrial metalcore',
#  'masterful meme music mashups',
#  "weirdo rap that's really strange",
#  'etherial wave',
#  'demo rock',
#  'mashup',
#  'space-age lounge rock',
#  'horror punk',
#  'synch pop',
#  'jungle',
#  'prog',
#  'indie country',
#  'garage punk',
#  'neo jazz',
#  'ode to radio',
#  'instrumental rock',
#  'grimy storytelling',
#  'mafioso rap',
#  'improvised sludge metal',
#  'electronic pop',
#  'no swedish songwriters',
#  'grunge a little bit?',
#  'post-funkcore with noise and more funk',
#  'futuristic purple sound',
#  'noise pop',
#  'unhappiness',
#  'emo trap',
#  'avant-neo-soul',
#  'grime',
#  'ambient music',
#  'maybe post-rock at moments',
#  'scream raps',
#  'eccentric progressive electropop magic',
#  'neo-new wave',
#  'dream pop',
#  'metalcore',
#  'psych',
#  'nostalgic noise and dissonance',
#  'baroque pop',
#  'nu-disco',
#  'avant-garde jazz',
#  'minimalism',
#  'shoehop',
#  'holy wow this rules',
#  'bar band rock',
#  'avant-folk',
#  'weirdmeoutstuff',
#  'folk metal',
#  'psychedelic rock',
#  'lo-fi psych soul',
#  'sludge punk',
#  '90s nostalgia',
#  'vamp trap',
#  'speed metal',
#  'internet rap',
#  'trapped & screwed bap jazz rap amalgamation',
#  'orchestral',
#  'post-minimalism',
#  '"d.c. sound"',
#  'jazz rap instrumentals made from grimy live recordings and chopped up nicely',
#  'mediterranean horn punk',
#  'electronic jazz fusion magic',
#  'death metal',
#  'futurepop',
#  'post-bop',
#  'spoken word post-avant-art-thrash-core',
#  'soft jazz pop',
#  'power electronics',
#  'insane black metal covers',
#  'acid techno',
#  'satanic-space-jams',
#  'subtle electronic rock magic',
#  'jazz & psych rap',
#  'noise rock',
#  'spiritual jazz',
#  'chiptune',
#  'alternative singer-songwriter',
#  'noise metal',
#  'psych trap',
#  'poppy funky goodtimes',
#  'breakup rock',
#  'post-punk',
#  'post-punk (modernized)',
#  'quaint soundtrack-worky lo-fi instrumentals',
#  'pop',
#  'atmospheric black metal',
#  'electroacoustic repetition voodoo',
#  'big laughs and tons of fun',
#  'smooth rap',
#  'big beat',
#  'dancehall',
#  'assembly line terrors',
#  'no no no no no',
#  'afrobeat',
#  'trap metal',
#  'sorta conscious hip hop',
#  'glitch pop',
#  '(relatively) hardcore hip hop',
#  'collage music',
#  'beat music',
#  'glistening indie pop',
#  'folktronica',
#  'dance punk',
#  'arena rock',
#  'experimental electronica',
#  'microtonal',
#  'ambient',
#  'sad boiband',
#  'trap&b',
#  'raprock',
#  'psych rap',
#  'depressive swedish punk',
#  'ambient dub',
#  'freeform rock',
#  'disco',
#  'hyphy',
#  'r&b-ish',
#  'witch house',
#  'post-pop-catchy-sludge (lol)',
#  'african electronica',
#  "hard-as-nails cloud rap that doesn't screw around",
#  'contemporary r&b',
#  'synth pop',
#  'gothic metal',
#  'neofolk',
#  'electrodisco',
#  'stoner rock (slightly)',
#  'twee + jangle pop',
#  'hardcore hip hop',
#  'psychedelic sound terrorism',
#  'musique concrete',
#  'symphonic rock',
#  'absolutely twisted shit',
#  'progressive rock',
#  'soundtrack creepiness',
#  'chipstep',
#  'industrial rock',
#  'nocturnal breaks',
#  'minimal',
#  'baroque',
#  'progressive pop',
#  'cybergrind',
#  'tech house',
#  'strange plinky plonky crazy instrumentals that are somewhat boss',
#  'and a dab of technical death metal',
#  'metallic zaniness',
#  'noise hop',
#  'alt-metal',
#  'singer-songwriter,',
#  'future bass',
#  'introspective gangsta rap',
#  'moombahton',
#  'latin pop',
#  'sterile pop rock',
#  'idm',
#  'surf rock',
#  'art pop',
#  'reggaeton',
#  'ny drill',
#  'jangel pop',
#  "lo-fi rock 'n' roll",
#  'neo soul',
#  'baroque music',
#  'new york hardcore',
#  'beatdown hardcore',
#  'all sorts of house',
#  'alternative dance',
#  'no trap beats',
#  'lullabyes',
#  'electrogrind',
#  'death grips 2.0',
#  'cloud folk',
#  'have you ever heard of this band called "the cure"?',
#  'cuban rumba',
#  'reggae',
#  'punk blues',
#  'ambient hip hop',
#  'chillwave',
#  'breakbeat electronica',
#  'nouvelle chanson',
#  'conscious hip hop',
#  'breakcore',
#  'progressive elecronic',
#  'bar band ballads',
#  'slightly post-rock-ish moment',
#  'deep house',
#  'blues',
#  'generative music',
#  'punk rock',
#  'conceptual mental illness rock operas',
#  'chamber music',
#  'a little bit of post-punk here and there',
#  'fidget house',
#  'blackened post-punk',
#  'harsh noise hyphy hop',
#  'electro',
#  'reverb rock',
#  'inter-dimensional ear candy',
#  'liturgical music',
#  'korean traditional music',
#  'psychedelic raps',
#  'nwobhm',
#  'psychedelic warped noise magic',
#  'funk rock',
#  'screamo',
#  'mathcore',
#  'surf punk',
#  'kinda edm',
#  'dirty south',
#  'stoner pop',
#  'progressive house',
#  'a touch of grunge',
#  'brostep',
#  'mosh riffs and mosh riffs and mosh riffs',
#  'dreamy chamber pop',
#  'crossover',
#  'creepy spoken word passages',
#  'contemporary classical',
#  'trippy pop magic future stuff',
#  'internet raps',
#  'blackened doom metal',
#  'ethereal bangers',
#  'atmospheric sludge metal',
#  'dreary and soft electronic pop tunes',
#  'glitch',
#  'pop punk',
#  'math rock',
#  'gothic rock',
#  'kraut rock',
#  'post-post-hardcore',
#  'free improvisational',
#  'pop country',
#  'bars!!',
#  'j-rap',
#  'post-emo',
#  'riot grrrl',
#  'psychedelic sludge or doom with string arrangements and dismal lyrics',
#  'europop',
#  'sorta conscious but also drugged out',
#  'garage rock revival',
#  'twangy dream rock',
#  'spazzcore',
#  'creepy covers',
#  'country rap',
#  'trippy "g" magic',
#  'midwest emo',
#  '"there\'s even a ska song"',
#  'neo-psychedelia',
#  'ritual ambient',
#  'stoner metal',
#  '80s nostalgia',
#  'uk hip hop',
#  'sound collage',
#  'dream jazz',
#  'horrorcore',
#  'drumless',
#  'adult contemporary',
#  'soundtrack',
#  'jazz poetry',
#  'industrial noise',
#  'micro house',
#  'sampling insanity',
#  'eccentric electro trap rap',
#  'new jack swing',
#  'slightly improvised nightmares',
#  'progressive synth',
#  'wonky techno',
#  'electronic thom yorke magic',
#  'electro-afro-funk',
#  'progressive electronic',
#  'ghost raps',
#  'grindcore',
#  'irregular techno magic',
#  'holy wow crazy lyrics',
#  'd.c. anonymity',
#  'experimental hip hop',
#  'emocorewhatever',
#  'elecronic',
#  'country trap',
#  'contemporary flamenco',
#  'trying to punk',
#  'whisper raps',
#  'rap rock',
#  '.....cloud rap',
#  'swag rapsz',
#  'poetry',
#  'kinda sorta folk rock with an attitude',
#  'trippy ensemble',
#  'bad dancehall',
#  'patton-core',
#  'memphis rap',
#  'indie folk,',
#  'cold wave',
#  'groove metal',
#  'post-folk',
#  'experimental jazz',
#  'neo-soul from the future',
#  'samba jazz',
#  'amsr',
#  'doom metal',
#  'top-40 magic',
#  'jazz fusion',
#  'occult shit',
#  'bubblegum bass',
#  'wordy rock',
#  'post-new age',
#  'too.',
#  'thrash punk',
#  'soul',
#  'psych raps',
#  'a bit of post-hardcore as well',
#  'alternative r&b',
#  'shoegaze',
#  'swag rap',
#  'wallpaper funk',
#  'heavy psych',
#  'hip house',
#  'shouted word',
#  'psych soul',
#  'sort of referencing vaporwave',
#  'slick singer-songwriter dude',
#  'experimental rock',
#  'indietronic',
#  'amazing shit.',
#  'conscious rap',
#  'sludge metal',
#  'deconstructed reggaeton',
#  'experimental electronic',
#  'choral pop',
#  'lo-fi indie',
#  'personal raps',
#  'minimal techno',
#  'ndh',
#  'bruiser',
#  'jazz rap a couple of times',
#  'grimy raps with dirty synthetic beats from hell topped with dark rhymes',
#  'sludgecore',
#  'moody and depressing r&b',
#  'orchestral rap',
#  'industrial trying',
#  "death metal death 'n' roll",
#  'art raps',
#  'alternative rock',
#  'outsider  music',
#  'lo-fi abstract hip hop',
#  'death doom metal',
#  'alternative country',
#  'tribal ambient',
#  'power pop,',
#  'singer-songwriter',
#  'gothic country',
#  'trance',
#  'chamber pop',
#  'rowdy bangers',
#  'minimal piano magic',
#  '"far&b"',
#  "death 'n' roll",
#  'electo house',
#  'heady wordplay magic',
#  'uk bass',
#  'satirical hardcore',
#  'hardcore hip hip',
#  'lo-fi soul mixed with african rhythms',
#  'electronic relaxation',
#  'gagaku-infused ambient & drone',
#  'jazzed up bangers',
#  'darkened dancepop',
#  'instrumental hip hop',
#  'alternative r&b from another dimension',
#  'minimal synth',
#  'contemporary folk',
#  'funk',
#  'gothic hypnagogic pop',
#  "dark rock 'n' roll",
#  'domino',
#  'no features',
#  'neo-folk',
#  'sophisti-pop',
#  'tarot trap',
#  'hellfyre magic',
#  'goth-ish',
#  'nu jazz',
#  'tread punk',
#  'acid house',
#  'soundcloud raps',
#  'art freak',
#  'vintage retro trip hop',
#  'emocore',
#  'rapgaze',
#  'drone metal',
#  'instrumental smooth rock',
#  'choral',
#  'prog folk',
#  'dream folk magic',
#  'abstract hip hp',
#  'dance-punk',
#  'detroit hip hop',
#  "drum 'n' bass",
#  'chamber music...in a cave',
#  'death metal growl magic',
#  'alt-pop',
#  'bedroom pop',
#  'lo-fi',
#  'uh......r&b....sorta....',
#  'fauxgaze',
#  "rock 'n' roll",
#  'aor',
#  'blackened industrial doom rock spoken word yeah',
#  'auto-tuned noise hop. house hop',
#  'the boss',
#  'avant-garde metal',
#  'spoken hop',
#  'glam rock',
#  'somewhat drone-y techno',
#  'heavy as hell power ballad melodies',
#  'mod rock',
#  'folk rock',
#  'neo-psychedelic-soul-grunge...rap',
#  'international bangers for truth and dance',
#  'indietronica',
#  'comedy rock',
#  'evil doo-wop',
#  "drill 'n' bass",
#  'electro pop',
#  'smart rapper from canada with a lot of clever stuff to say',
#  'synthpop',
#  'i suppose',
#  'dad rock',
#  'harcore hip hop',
#  'electro house',
#  'beast coast magic',
#  'sludge pop',
#  'psychopathic british invasion revivalism',
#  'electro-disco',
#  'psychedelic black metal',
#  'synth  pop',
#  'chillwave vibes',
#  'balkan brass',
#  "maybe there's some black metal in there as well",
#  'country',
#  'heavy metal',
#  'east coast hip hop',
#  'transcendental black metal',
#  'wonky',
#  'technical death metal',
#  'cowpunk',
#  'electrofunk',
#  'gritty eerie lyrical east coast raps',
#  'microhouse',
#  'lo-fi refinement',
#  'emotional rhyme time',
#  'blackgaze',
#  'experimental music',
#  'abstract hip hop',
#  'trap',
#  'afro-jazz',
#  'psychedelic hip hop',
#  'emotional piano magic',
#  'super bangers',
#  'blues rock',
#  'psychedelic (sort of) pop',
#  'epic poet stories',
#  'emotional trainwreck music',
#  'post-nostalgia',
#  'look at the album cover',
#  'cumbia',
#  'crust punk',
#  'eurodance',
#  'southern soul',
#  'auto-tuned rap ballads',
#  'pure electronic insanity',
#  "a lil bit o' shoegaze",
#  'blockhead instrumental magic',
#  'indie electronic',
#  'crossover thrash',
#  'a bit of folk influence as well',
#  'anti-folk',
#  'g funk',
#  'free jazz',
#  'daniel johnston pastiche',
#  'self-help arena rock opera',
#  'progressive metal',
#  'drone doom',
#  'post-hardcore and pop punk hybrid magic',
#  'plunderphonics',
#  'post-metal',
#  'd-beat',
#  'rock',
#  'blackened psych',
#  'country pop',
#  'uh',
#  'indie',
#  'contemporary r&b circa 1985',
#  'future soul',
#  'future trap',
#  'nu-jazz',
#  'fuzzyness',
#  'vintage psychedelic pop',
#  'avant-reggaeton',
#  'dream wave',
#  '"hypnagogic pop"',
#  'lo-fi hip hop',
#  'freak salsa',
#  'synth-rap',
#  'hardcore punk',
#  'edm',
#  'brazilian avant-garde',
#  'experimental electronic magic',
#  'lots of gecs',
#  'ambient house',
#  'alt-country',
#  "drum 'n' glitch",
#  'free jazz?',
#  'slowcore hip hop',
#  'funk carioca',
#  'avant-prog',
#  'art punk',
#  'korean folk',
#  'nothing was the same-core',
#  'grunge',
#  'electronic neo-psych',
#  'vintage dance jams',
#  'avant-garde',
#  'auto-tuned dream rap ballads that feel good',
#  'bedroom soul',
#  'jazz funk',
#  'tuvan throat singing',
#  'thrash metal',
#  'jazzrock',
#  'contemporary country',
#  'chamber folk',
#  'microphones... in 2020',
#  'smooth funk',
#  'nan',
#  'comedy rap',
#  'electronic nu metal linkin park fusion',
#  'post-hip hop',
#  'violent and frightening grind',
#  'dubstep fusion',
#  'neo-soul',
#  'decent club anthems',
#  'klezmer',
#  'avant folk',
#  'drum n bass',
#  'theatrical whispers',
#  'gospel',
#  'athsmatic kitty',
#  'indie popd',
#  'experimental electronics',
#  'experimental',
#  '"rage"',
#  'goth rock',
#  'tape music',
#  'lo-fi rock',
#  'lo-fi pop',
#  'balloucore',
#  'electroacoustic',
#  'funky soul pop',
#  'midi classical',
#  'alternative hip hop',
#  'rockabilly...sort of...',
#  'digital hardcore',
#  'w but still ratio',
#  'folktronic',
#  'vocal pop',
#  'k-pop',
#  'alt rock',
#  'latin trap',
#  'trip hop',
#  'psychedelic pop',
#  'a bit of horrorcore',
#  'too...',
#  '20 buck spin',
#  'electro-industrial',
#  'gangsta rap',
#  'sweet dreams',
#  'moody hardcore hip hop',
#  'death and heavy metal fusions',
#  'neo-psych',
#  '"post-rock," art rock',
#  'digital cumbia',
#  '100% pure uncut rock',
#  'neo-classical',
#  'personal piano tunes of tragedy and romance',
#  'goth trap',
#  'zombie rockabilly',
#  'smooth soul',
#  'instrumental rock with electronic fusion magic',
#  'stoner rock',
#  'primus?',
#  'uk funky',
#  'pop rock',
#  'modal jazz',
#  'deathcore',
#  'hardcore breaks',
#  'new wave',
#  'multi-genre combo (tasteful)',
#  'blackened thrash metal',
#  'gothic hip hop',
#  'instrumental',
#  'post-hardcore',
#  'gentrified reggae jams',
#  'electro-industrial dance party',
#  'post-bone thugs',
#  'water level rap',
#  'experimental choral music',
#  'jazz-funk',
#  'santeria music  with a baroque twist',
#  'new orleans r&b',
#  'sludge',
#  'neoclassical darkwave',
#  'bitpop',
#  'disco indie synth stuff with falsetto vocals',
#  'progressive',
#  'reverb addiction',
#  'freak folk',
#  'extreme sludge magic',
#  'edm jamz',
#  'minimalist groove jazz',
#  'mr. bungle vibes',
#  'ska',
#  'i think',
#  'experimental blues rock',
#  'dangerous nostalgiaa',
#  'melodic hardcore',
#  'party cock rock core',
#  'deathgrind',
#  'apocalypse-hop',
#  'psych folk',
#  'luxurious jazz rap',
#  'instrumental pop',
#  'americana',
#  'experimental pop',
#  'genre-blending indie pop',
#  'heartland rock',
#  'horror synth',
#  'chopped & screwed',
#  'crossover country',
#  'dub techno',
#  '5 autotuned kanyes singing through a simultaneousa heart attack.',
#  'opera',
#  'darkwave',
#  'black metal',
#  'alt metal',
#  "washing machine sample music that's awesome",
#  'piano cuteness',
#  'classical',
#  'punk',
#  'soul jazz',
#  'post-grunge',
#  'psychedelic metal',
#  'blackened death metal',
#  'tribal house',
#  'future garage',
#  'g.o.o.d. music',
#  'collaborative electro-industrial',
#  '"brostep"',
#  'ska punk',
#  'twee pop',
#  'minimalist rock',
#  'mark kozelek',
#  'southern hip hop',
#  'lo-fi auto-tune ballads',
#  'death thrash hxc funny times with cool stories',
#  'sweet beats',
#  'rave',
#  'overly atmospheric synth pop',
#  'psychedelic beat magic',
#  "cuz it's not really that lo-fi)",
#  'tech death',
#  'psychedelic',
#  'alternative metal',
#  'ambient & glitch pop',
#  'doom electronics',
#  'downtempo',
#  'horrorcore (slightly)',
#  'watered-down dancehall',
#  'slowcore-ish',
#  'thrash',
#  'breakbeat',
#  '(conscious) trap',
#  'melo-trap',
#  'power pop',
#  'new age',
#  'drill',
#  'good jazzy times',
#  'southern rock',
#  'melodic death metal',
#  'marching band',
#  'traditional doom metal',
#  'garage pop',
#  'traditional',
#  'post-modern classical',
#  'noisecore',
#  'christian hip hop',
#  'jazz rap',
#  'art rock',
#  'folk',
#  '80s hard rock guitar heroism viewed through a lo-fi lens',
#  'pop folk punk grimyness',
#  'sampledelica',
#  'political hip hop',
#  'island music pop magic',
#  'futuristic neo-soul',
#  'dead bodies',
#  'bad goth',
#  'musical parody',
#  'odd future raps',
#  'psychedelic folk rock',
#  'jazz rock',
#  'lynchian horror',
#  'industrial hip hop instrumentals',
#  'new age rock magic',
#  'minimal hip hop',
#  'avant-pop',
#  'lofty post-house',
#  'minimalist rap',
#  'drum machine metal that rips your face off',
#  'blue eyed soul',
#  'silly bars',
#  'caveman tunes',
#  'folk pop',
#  'depressing punk jamz',
#  'xmas raps',
#  'jazz',
#  'dark folk',
#  'film soundtrack',
#  'moody electronica atmospheres',
#  'emo',
#  'traditional pop',
#  'bang bang boom',
#  'industrial',
#  'minimal wave',
#  'sonic spelunking',
#  'latin jazz',
#  'glitchy gangsta rap or "glitch-sta rap"',
#  'semi-futuristic smooth soul',
#  'noise rap',
#  'psych pop',
#  'drone',
#  'progressive groove metal',
#  'wtf is going on mark?',
#  'future house',
#  'soundcloud rap',
#  'experimental future electronic beat music from out of this world',
#  'dream reggae',
#  'alt-rock',
#  'pop rap with trap vibes on the instrumentals',
#  'brutal death metal',
#  'there are elements of drone spattered throughout this album',
#  "every friggin' kind out there what the fuck this is crazy!",
#  'hipgaze',
#  'new york drill',
#  'trippy trap',
#  'hypnagogic pop',
#  'boom bap',
#  'sorta psychedelic trap crooner stuff',
#  'drum and bass',
#  'what the title says',
#  'lei music',
#  'post-industrial',
#  'ambient pop',
#  'field recordings',
#  'indie rock',
#  'country soul',
#  'hijacked pop rap',
#  'rock poet madness',
#  'nu metal',
#  'soft rock',
#  'psychedelic rap magic',
#  'drill and bass',
#  'beatmusic',
#  'japanese hardcore',
#  'footwork',
#  'synthwave',
#  'progressive folk',
#  'vaporwave',
#  'texture beatz',
#  'g-funk',
#  'dnb',
#  'post-vaporwave',
#  'classic dirty mystic stylezzz magic',
#  'slowcore',
#  'ambient techno',
#  "some kind of weird and dark metal music that isn't really metal but is also amazingly dark",
#  'eai',
#  'abstract hip hop (sorta)',
#  'everything a. g. cook does',
#  'interstellar collaboration',
#  'post-crunkcore',
#  'new york hip hop',
#  'transcendental auditory experience',
#  "conscious hip hop but don't call it that",
#  'flamenco pop',
#  'alternative funk jazz fusion',
#  'alt pop',
#  'post-rock',
#  'blackened vapor',
#  'dub',
#  'nuclear blast',
#  'post-classical',
#  'rap metal',
#  'sad trap electronica magic',
#  'space rock',
#  'dance rock',
#  'colorful hardgrooves',
#  'electronica',
#  'synth funk',
#  'd9',
#  'jam band',
#  'trap music',
#  'heart punk',
#  'experimental metal',
#  'psych electronics',
#  'etc.',
#  'super quiet raps',
#  'new atlanta',
#  'r&b',
#  'electropop',
#  'dance-pop',
#  'jazzy blackened tech-death',
#  'britpop',
#  'confounding raps',
#  'piano rock',
#  'glitchy dance magic',
#  'kinda shoegaze',
#  'ambient trance',
#  'industrial pop',
#  'thoughtful raps',
#  'post rock',
#  'nature recordings',
#  'dancefloor strangeness',
#  'sonic sorcery',
#  'industrial metal',
#  'conscious uk hip hop',
#  'international sounds with a western freakishness',
#  'grimy soul',
#  'all kinds of pop and sometimes metal',
#  'water rap',
#  'vintage vocal pop',
#  '2-step',
#  'vintage nostalgia sugar magic',
#  'poet punk',
#  'brit pop',
#  'progressive death metal',
#  'incredibly lackluster internet rap with gimmicky vocals',
#  'post-punk revival',
#  'softpop',
#  'novelty rap that wishes it was something else',
#  'reverb',
#  'twee',
#  'jazz pop',
#  'rap',
#  'african music',
#  'dark depressing hop',
#  'death grind',
#  'musical stories',
#  'memphis raps',
#  'neo folk',
#  'purple sound',
#  'ethereal pop',
#  'chamber screamo',
#  'west coast hip hop',
#  'riff mania',
#  'harsh house',
#  'indie pop',
#  'conceptual space raps',
#  'acoustic ballads',
#  'yawk yawk yawk yawk',
#  'occasionally conscious hip hop',
#  'drill n bass',
#  'dystopian art punk',
#  'contmporary r&b',
#  'electronic',
#  'dream folk',
#  'post-punky beach rock vibes',
#  'boogie rock',
#  'psych rock',
#  'pop rap. socially conscious hip hop',
#  'country rock',
#  'grimy new york shiz',
#  'indie folk',
#  'industrial hip hop',
#  'swag raps',
#  'african hip hop lo-fi noise fusion',
#  'sad hip hop',
#  'japanese hip hop',
#  'uk garage',
#  'westernized dancehall',
#  'post-rave',
#  '80s nostalgia pop',
#  'math metal',
#  'chamber jazz',
#  'future pop',
#  'stoner doom metal',
#  "bachelor's degree in english trap raps",
#  'ambient folk',
#  'juke',
#  'experimental indie techno',
#  'grunge rap',
#  'experimental r&b',
#  'glam metal',
#  'latin american folk music',
#  'mac miller-core',
#  'deconstructed club',
#  'new chanson',
#  'folk punk',
#  'techno',
#  'house',
#  'garage rock',
#  'post-trap',
#  'coldwave',
#  'spoken word',
#  'psychedelic soul',
#  'power noise',
#  'sprituals',
#  'church organ drones',
#  'tenderpunk',
#  'quarantine bops',
#  'emo pop',
#  'experimental instrumental hip hop',
#  'funeral rave',
#  'bangers',
#  'death-doom',
#  'c86',
#  'alternative pop',
#  'gothic & atmospheric sludge metal',
#  'acid punk',
#  'electro disco',
#  'cloud rap?',
#  'glam',
#  'two-step',
#  'futuristic death metal',
#  'neo psych',
#  'tech-death',
#  'hip hop',
#  'contemporary pop',
#  'eighties vibes',
#  'turntablism',
#  'poetic art punk american rock western southern folk freak what am i even saying?',
#  'a capella',
#  'worldbeat',
#  'outlaw country',
#  'melodic metalcore',
#  'hardcore',
#  'pop soul',
#  'synth punk',
#  'electro rock',
#  'nutty futuristic pop',
#  'eurodance from hell',
#  'hard rock',
#  'noise metal harshness from hell',
#  'blue grass',
#  'prog rock',
#  'neo-new wave for strange people with senses of humor',
#  'gospel trap',
#  'deadpan',
#  'pglang',
#  'dark jazz',
#  'industrial apocalypse',
#  'glitch&b',
#  'death doom',
#  'sleepy pop',
#  'death industrial',
#  'micro  house',
#  'anatolian rock',
#  'cloud singing pop',
#  'blood-boiling rants',
#  'ethereal wave',
#  'trap rap',
#  'memetic mashups',
#  'emo rap',
#  'absurdist post-modernism',
#  'hellfyre hip hop',
#  'latin funk',
#  'experimental folk',
#  'microtonal psych rock',
#  'noise',
#  'skate punk',
#  '"recks on" has a bit of a hip hop flavor to it',
#  '3rd eye shit',
#  'skull-crushing destruction from hell',
#  'arabic jazz',
#  'deathbomb arc vibes',
#  'ethereal darkwave',
#  'dream punk',
#  'soft punk',
#  'soul funk hip hop r&b fusion',
#  'punderphonics',
#  'gothic americana',
#  'alternative',
#  'technical thrash metal',
#  'goregrind',
#  'djent',
#  'heavy nihilistic sludge punk',
#  'electric cumbia',
#  'mexican folk music',
#  'old vintage retro lo-fi revisitation of all the major rock icons ever',
#  ...}

# %%
reviews.get_by_genre_substr("pop").mean_rating()
# Out:
# (5.9330900243309, 822)

# %%
POPULAR_GENRES = [
    "pop", 
    "hip hop",
    "electronic", 
    "rock",
    "r&b",
    "country", 
    "metal",
    "singer-songwriter",
    "folk",
    "indie",
    "ambient",
    "soul",
    "funk",
    "house",
    "punk",
    "industrial",
    "psychedelic"
]

# %%
data = [(genre, reviews.get_by_genre_substr(genre).mean_rating()) for genre in POPULAR_GENRES]
data = [(genre, rating, num_reviews) for (genre, (rating, num_reviews)) in data]

df = pd.DataFrame(data, columns=["genre", "rating", "num_reviews"]).sort_values("rating", ascending=False)

sns.set(rc = {'figure.figsize':(10,10)})
sns.barplot(x="rating", y="genre", data=df, estimator=sum).set(title='Mean ratings for popular genres')
# Out:
# [Text(0.5, 1.0, 'Mean ratings for popular genres')]

# %%
reviews.get_by_artist("").df
# Out:
# Empty DataFrame
# Columns: [publishedAt, title, artist, rating, genres]
# Index: []
